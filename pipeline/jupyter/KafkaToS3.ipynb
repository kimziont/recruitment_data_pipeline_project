# %%
import json
import boto3
from kafka import KafkaConsumer

# %%
access_key_id = 'AKIAUKJSSORFOCZGKI5K'
secret_access_key = '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'
bucket_name = 'ziontkim-recruitment-1'

s3 = boto3.resource('s3', aws_access_key_id=access_key_id, aws_secret_access_key=secret_access_key)

# %%
topicName = 'recruitmentProgrammers'
brokers = ['kafka:29092']

# %%
for i in range(5):
    try:
        consumer = KafkaConsumer(topicName, bootstrap_servers=brokers, group_id='1', auto_offset_reset='smallest', consumer_timeout_ms=10000)
        print(f'{i + 1}번 째 연결 성공')
        print(type(consumer))
        break
    except Exception as e:
        print(e)
        print(f'{i + 1}번 째 연결 실패')
else:
    print('Kafka를 연결할 수 없습니다')


folder_name = 'programmers/'
paginator = s3.meta.client.get_paginator('list_objects_v2')

response_iterator = paginator.paginate(
    Bucket='ziontkim-recruitment-1',
    Prefix='programmers/'
)

all_s3_objects = set()
for page in response_iterator:
    for content in page['Contents']:
        all_s3_objects.add(content['Key'])
# Out:
# NoBrokersAvailable
# 1번 째 연결 실패
# 2번 째 연결 성공
# <class 'kafka.consumer.group.KafkaConsumer'>

# %%
for message in consumer:
    consumer.commit()
    row = json.loads(message.value.decode())
    # Kafka에서 S3로 저장
    row['Title'] = row['Title'].replace('/', '_')
    print(row['Title'])
    row['Company'] = row['Company'].replace('/', '_')
    file_name = folder_name + row['Company'] + row['Title'] + '.json'
    # 새로 크롤링된 데이터인 경우
    if file_name not in all_s3_objects:
        print(f"{file_name} is stored in S3")
        s3.meta.client.put_object(Body=json.dumps(row).encode("utf-8"),
                              Bucket=bucket_name,
                              Key=file_name)
    else:
        body = s3.meta.client.get_object(Bucket=bucket_name,
                                 Key=file_name)['Body']
        s3_data = json.loads(body.read().decode())
        # 수정/업데이트 된 경우
        if row['LastModifiedTime'] != s3_data['LastModifiedTime']:
            s3.meta.client.put_object(Body=json.dumps(row).encode("utf-8"),
                                  Bucket=bucket_name,
                                  Key=file_name)

consumer.close()
# Out:
# [패스오더] 백엔드 개발자 (Spring, Python, MSA)
# AI 엔지니어
# [패스오더] 데이터 엔지니어(그로스해커)
# [부산지역] 선별관제 솔루션 필드 엔지니어 부문
# 데이터 엔지니어
# 데이터 엔지니어
# 산업용 설비 데이터 분석가
# [인포보스]인공지능개발팀(산업기능요원, 전문연구요원 가능)
# 데이터 엔지니어
# ML Engineer
# [패스오더] 백엔드(Spring, Python, MSA)개발자 (병역특례 산업기능요원 보충역_전직가능)
# 클라우드 사업실(마이데이터, APIM) 개발자
# [웨이브릿지] DW Engineer
# Data Scientist
# ML Engineering (강화학습 기반 건축설계 자동화 엔진 개발)
# Data Engineer
# [에너지 IT기업 해줌] 백엔드 개발자
# 데이터 크롤링 및 시스템 구축 엔지니어
# 데이터 엔지니어(Data Engineer)
# 빅데이터플랫폼개발자
# Data Scientist (데이터 사이언티스트)(병역특례 가능)
# 데이터수집 플랫폼개발자
# 데이터 분석가(Data Analyst)
# 데이터 분석가
# [전문연구요원] Software Engineer, Data
# Software Engineer (산업기능요원)
# Data Engineer (Data ETL Engineer)
# Public Cloud Engineer
# AI PM(팀장 이상 급) 및 개발자(AI, 빅데이터 분야)
# ML 엔지니어
# Software Engineer, Data
# Visual  Geo-localization  Researcher
# Data Engineer
# Data Engineer (데이터 엔지니어)
# Back-end Engineer (백엔드 엔지니어)
# Detection Engineer
# Data Scientist
# 데이터 분석 알고리즘 개발자(석_박사급)
# 백엔드 개발자
# [AI Startup] AI Researcher _ Engineer
# 데이터 엔지니어
# 백엔드 경력 개발자 모집
# Data Platform Software Engineer (Senior_Junior)
# AI Engineer
# [윌라] 데이터 엔지니어
# Deep learning Engineer
# Data Scientist
# 서버 개발자
# (R&D) 플랫폼 개발 MLOps
# Machine Learning Engineer
# 웹풀스택 (데이터융합 웹서비스 플랫폼 개발)
# DevOps 엔지니어
# Perception Engineer
# [패스오더] 백엔드 개발자 (Spring, Python, MSA)
# AI 엔지니어
# [패스오더] 데이터 엔지니어(그로스해커)
# [부산지역] 선별관제 솔루션 필드 엔지니어 부문
# 데이터 엔지니어
# 데이터 엔지니어
# 산업용 설비 데이터 분석가
# [인포보스]인공지능개발팀(산업기능요원, 전문연구요원 가능)
# 데이터 엔지니어
# ML Engineer
# [패스오더] 백엔드(Spring, Python, MSA)개발자 (병역특례 산업기능요원 보충역_전직가능)
# 클라우드 사업실(마이데이터, APIM) 개발자
# [웨이브릿지] DW Engineer
# Data Scientist
# ML Engineering (강화학습 기반 건축설계 자동화 엔진 개발)
# Data Engineer
# [에너지 IT기업 해줌] 백엔드 개발자
# 데이터 크롤링 및 시스템 구축 엔지니어
# 데이터 엔지니어(Data Engineer)
# 빅데이터플랫폼개발자
# Data Scientist (데이터 사이언티스트)(병역특례 가능)
# 데이터수집 플랫폼개발자
# 데이터 분석가(Data Analyst)
# 데이터 분석가
# [전문연구요원] Software Engineer, Data
# Software Engineer (산업기능요원)
# Data Engineer (Data ETL Engineer)
# Public Cloud Engineer
# AI PM(팀장 이상 급) 및 개발자(AI, 빅데이터 분야)
# ML 엔지니어
# Software Engineer, Data
# Visual  Geo-localization  Researcher
# Data Engineer
# Data Engineer (데이터 엔지니어)
# Back-end Engineer (백엔드 엔지니어)
# Detection Engineer
# Data Scientist
# 데이터 분석 알고리즘 개발자(석_박사급)
# 백엔드 개발자
# [AI Startup] AI Researcher _ Engineer
# 데이터 엔지니어
# 백엔드 경력 개발자 모집
# Data Platform Software Engineer (Senior_Junior)
# AI Engineer
# [윌라] 데이터 엔지니어
# Deep learning Engineer
# Data Scientist
# 서버 개발자
# (R&D) 플랫폼 개발 MLOps
# Machine Learning Engineer
# 웹풀스택 (데이터융합 웹서비스 플랫폼 개발)
# DevOps 엔지니어
# Perception Engineer
# [기업부설연구소] Robotics Perception 개발
# [기업부설연구소] Visual_LiDAR SLAM 개발
# [기업부설연구소] 자율주행 개발
